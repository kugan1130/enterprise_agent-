# %% [markdown]
# # End-to-End Multi-Agent System Evaluation Benchmark
#
# Runs the 25-case evaluation dataset across DIRECT, RAG, WEB, SQL, MULTI-AGENT RESEARCH, SAFETY, MEMORY, and REFLECTION categories.

# %%
import sys
from pathlib import Path

# Resolve project root
cwd = Path.cwd().resolve()
if cwd.name == "tests":
    project_root = cwd.parent.parent
elif cwd.name == "backend":
    project_root = cwd.parent
else:
    project_root = cwd

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from backend.tests.eval_runner import run_evaluation

# Execute evaluation runner
await run_evaluation()
